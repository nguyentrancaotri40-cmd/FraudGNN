# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/.gitignore
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/audit_runtime.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/README.md
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/python
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/note.txt
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/requirements.txt
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/tests/test_preprocess.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/tests/test_federated.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/tests/test_model.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/tests/test_graph.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/tests/test_adversarial.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/tests/test_pruning.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/tests/test_pipeline.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/tests/__init__.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/scripts/utils/preprocess.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/scripts/utils/build_graph.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/scripts/utils/__init__.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/scripts/eval/compare.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/scripts/eval/timing_summary.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/scripts/eval/plot.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/scripts/eval/concept_drift_test.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/scripts/run/run_ablation_with_robustness.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/scripts/run/run_ablation.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/scripts/run/run_ablation_timing.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/scripts/run/run_ablation_full.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/scripts/run/run_full_evaluation.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/scripts/sweep/sweep_threshold.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/configs/creditcard2023_sample.yaml
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/configs/ieee_cis.yaml
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/configs/creditcard2023.yaml
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/configs/test.yaml
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/configs/paysim_sample.yaml
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/configs/test_hybrid_federated.yaml
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/configs/paysim.yaml
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/configs/ieee_cis_sample.yaml
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/configs/ablation/creditcard2023/baseline_seed42.yaml
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/.vscode/settings.json
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/main_pipeline.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/__init__.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/utils/seed.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/utils/pruning.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/utils/config.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/utils/timer.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/utils/logger.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/models/tssgc.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/models/dqn_agent.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/models/naf_agent.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/models/fraudgnn_rl.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/models/__init__.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/models/classifier.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/eval/adversarial.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/eval/evaluate.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/eval/metrics.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/eval/__init__.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/eval/concept_drift.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/graph/soft_behavior_graph.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/graph/hybrid_graph.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/graph/build_graph.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/graph/graph_utils.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/graph/__init__.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/data/preprocess.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/data/load_data.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/data/__init__.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/data/split.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/train/train_rl.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/train/pipeline_fraudgnn.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/train/train_gnn.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/train/__init__.py
# /kaggle/input/datasets/nguyntrncaotr/model-chy-kaggle/src/train/federated.py
